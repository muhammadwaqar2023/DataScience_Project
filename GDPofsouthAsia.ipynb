# %% [markdown]
# # **Project Title:**
# "South Asian GDP Growth"
#
# # **Project Objective:**
# Investigate and analyze the economic and social indicators of South Asian countries to gain insights into their interrelationships, identify key factors influencing economic development, and provide data-driven recommendations for strategic decision-making.
#
# # Business Questions:
# # Economic Development:
#
# How do GDP and GDP per Capita vary among South Asian countries, and what patterns can be identified?
# Are there specific economic indicators that strongly correlate with overall economic development?
# # Social Indicators:
#
# What is the distribution of key social indicators, such as adult literacy rates and life expectancy, among South Asian countries?
# Are there correlations between social indicators and economic factors like GDP?
# # Income Class Distribution:
#
# What is the distribution of income classes among South Asian countries, and are there patterns or trends?
# How do income classes correlate with economic and social indicators?
# # Unemployment Analysis:
#
# How does the unemployment rate vary across different income classes in South Asian countries?
# Are there factors contributing to high or low unemployment rates?
# # Population Dynamics:
#
# What are the population differences among South Asian countries, and what factors contribute to these variations?
# How does population size relate to economic and social indicators?
# # Insights:
#
# # Economic Patterns:
#
# Identify countries with notable economic growth and understand the contributing factors.
# Explore temporal trends in GDP and GDP per Capita for insights into economic stability.
# # Social Development:
#
# Analyze correlations between economic indicators and social development metrics.
# Identify countries achieving a balance between economic growth and social progress.
# # Income Class Influences:
#
# Investigate the impact of income classes on various aspects, including education, healthcare, and infrastructure.
# Provide insights into the socioeconomic characteristics of different income classes.
# # Employment Trends:
#
# Explore factors influencing unemployment rates and provide recommendations for targeted interventions.
# Identify sectors with potential for job creation and economic growth.
# # Population Insights:
#
# Examine population dynamics and their implications for economic and social policies.
# Identify countries facing demographic challenges or opportunities.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
df = pd.read_csv('worlddata.csv')

# %%
df
# Out:
#          country electricity_access          gdp gdp_capita labor_rate  \
# 0    Afghanistan              90.08  18833227887     536.23      47.28
# 1        Albania              99.94  12856050812    4473.89      57.54
# 2        Algeria              99.49  1.67755E+11    4117.84      41.79
# 3         Angola                 43  70956376358    2395.27      77.28
# 4      Argentina               99.9  5.80182E+11   13246.88      59.17
# ..           ...                ...          ...        ...        ...
# 181    Venezuela              99.62           ..         ..      60.58
# 182      Vietnam              99.61  2.71954E+11    2903.81      76.38
# 183        Yemen              69.37  30552676660    1038.42      37.45
# 184       Zambia              36.75  23598684258     1382.2       58.7
# 185     Zimbabwe              41.39  23063189889    1573.35      65.91
#
#      labor_force land_area  life_expectancy adult_literacy water_access  \
# ...

# %%
df.shape
# Out:
# (186, 20)

# %%
print(df.isnull().sum())
# Out:
# country                0
# electricity_access     0
# gdp                    0
# gdp_capita             0
# labor_rate             0
# labor_force            0
# land_area              0
# life_expectancy        0
# adult_literacy         0
# water_access           0
# air_pollution          0
# population_density     0
# population             0
# alcohol_consumption    0
# unemployment_rate      0
# social_support         0
# freedom                0
# generosity             0
# income_class           0
# cpi                    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.fillna(0, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# country                0
# electricity_access     0
# gdp                    0
# gdp_capita             0
# labor_rate             0
# labor_force            0
# land_area              0
# life_expectancy        0
# adult_literacy         0
# water_access           0
# air_pollution          0
# population_density     0
# population             0
# alcohol_consumption    0
# unemployment_rate      0
# social_support         0
# freedom                0
# generosity             0
# income_class           0
# cpi                    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# Length: 186, dtype: bool

# %%
df
# Out:
#          country electricity_access          gdp gdp_capita labor_rate  \
# 0    Afghanistan              90.08  18833227887     536.23      47.28
# 1        Albania              99.94  12856050812    4473.89      57.54
# 2        Algeria              99.49  1.67755E+11    4117.84      41.79
# 3         Angola                 43  70956376358    2395.27      77.28
# 4      Argentina               99.9  5.80182E+11   13246.88      59.17
# ..           ...                ...          ...        ...        ...
# 181    Venezuela              99.62           ..         ..      60.58
# 182      Vietnam              99.61  2.71954E+11    2903.81      76.38
# 183        Yemen              69.37  30552676660    1038.42      37.45
# 184       Zambia              36.75  23598684258     1382.2       58.7
# 185     Zimbabwe              41.39  23063189889    1573.35      65.91
#
#      labor_force land_area  life_expectancy adult_literacy water_access  \
# ...

# %%
df.tail(5)
# Out:
#        country electricity_access          gdp gdp_capita labor_rate  \
# 181  Venezuela              99.62           ..         ..      60.58
# 182    Vietnam              99.61  2.71954E+11    2903.81      76.38
# 183      Yemen              69.37  30552676660    1038.42      37.45
# 184     Zambia              36.75  23598684258     1382.2       58.7
# 185   Zimbabwe              41.39  23063189889    1573.35      65.91
#
#      labor_force land_area  life_expectancy adult_literacy water_access  \
# 181  13210887.75    882050            72.25          96.87        94.31
# 182  54856780.25  313400.5            73.94             ..        93.84
# 183    6526029.5    527970            65.62             ..        57.27
# 184      5499897    743390            61.87          86.75        64.39
# 185    5551153.5    386850            60.51             ..        64.24
#
#     air_pollution population_density   population alcohol_consumption  \
# ...

# %%
df.dtypes
# Out:
# country                 object
# electricity_access      object
# gdp                     object
# gdp_capita              object
# labor_rate              object
# labor_force             object
# land_area               object
# life_expectancy        float64
# adult_literacy          object
# water_access            object
# air_pollution           object
# population_density      object
# population             float64
# alcohol_consumption     object
# unemployment_rate       object
# social_support          object
# freedom                 object
# generosity              object
# income_class            object
# cpi                     object
# dtype: object

# %%
df1 = ['gdp', 'gdp_capita', 'labor_rate', 'labor_force', 'land_area',
                       'adult_literacy', 'water_access', 'air_pollution', 'alcohol_consumption',
                       'unemployment_rate', 'social_support', 'freedom', 'generosity', 'cpi']

# Convert selected columns to numeric
df[df1] = df[df1].apply(pd.to_numeric, errors='coerce')

# %%
# Display data types after conversion
print(df.dtypes)
# Out:
# country                 object
# electricity_access      object
# gdp                    float64
# gdp_capita             float64
# labor_rate             float64
# labor_force            float64
# land_area              float64
# life_expectancy        float64
# adult_literacy         float64
# water_access           float64
# air_pollution          float64
# population_density      object
# population             float64
# alcohol_consumption    float64
# unemployment_rate      float64
# social_support         float64
# freedom                float64
# generosity             float64
# income_class            object
# cpi                    float64
# dtype: object

# %%
# Assuming your DataFrame is named 'df'
columns_to_remove = ['electricity_access', 'population_density', 'labor_rate', 'labor_force', 'water_access', 'air_pollution',
                      'alcohol_consumption', 'social_support', 'freedom', 'generosity', 'cpi']

# %%
# Remove specified columns
df = df.drop(columns=columns_to_remove)

# %%
# Display the DataFrame after removing columns
print(df.head())
# Out:
#        country           gdp  gdp_capita  land_area  life_expectancy  \
# 0  Afghanistan  1.883323e+10      536.23   652230.0            62.97
# 1      Albania  1.285605e+10     4473.89    27400.0            78.93
# 2      Algeria  1.677550e+11     4117.84  2381741.0            75.79
# 3       Angola  7.095638e+10     2395.27  1246700.0            61.39
# 4    Argentina  5.801820e+11    13246.88  2736690.0            76.73
#
#    adult_literacy   population  unemployment_rate         income_class
# 0             NaN  35179977.00             10.341           Low income
# 1           98.14   2874159.25             14.633  Upper middle income
# 2           81.41  40736509.00             10.540  Lower middle income
# 3             NaN  29691157.00              9.557  Lower middle income
# 4           99.10  43815411.75              8.301  Upper middle income

# %%
# Assuming your DataFrame is named 'df'
column_name_mapping = {
    'country': 'COUNTRY',
    'gdp': 'GDP',
    'gdp_capita': 'GDP_CAPITA',
    'land_area': 'LAND_AREA',
    'life_expectancy': 'LIFE_EXPECTANCY',
    'adult_literacy': 'ADULT_LITERACY',
    'population': 'POPULATION',
    'unemployment_rate': 'UNEMPLOYMENT_RATE',
    'income_class': 'INCOME_CLASS'
}

# %%
# Rename specified columns
df.rename(columns=column_name_mapping, inplace=True)

# %%
# Display the DataFrame after renaming columns
print(df.head())
# Out:
#        COUNTRY           GDP  GDP_CAPITA  LAND_AREA  LIFE_EXPECTANCY  \
# 0  Afghanistan  1.883323e+10      536.23   652230.0            62.97
# 1      Albania  1.285605e+10     4473.89    27400.0            78.93
# 2      Algeria  1.677550e+11     4117.84  2381741.0            75.79
# 3       Angola  7.095638e+10     2395.27  1246700.0            61.39
# 4    Argentina  5.801820e+11    13246.88  2736690.0            76.73
#
#    ADULT_LITERACY   POPULATION  UNEMPLOYMENT_RATE         INCOME_CLASS
# 0             NaN  35179977.00             10.341           Low income
# 1           98.14   2874159.25             14.633  Upper middle income
# 2           81.41  40736509.00             10.540  Lower middle income
# 3             NaN  29691157.00              9.557  Lower middle income
# 4           99.10  43815411.75              8.301  Upper middle income

# %%
# Assuming your DataFrame is named 'df'
south_asian_countries = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# %%
# Specify the columns you want to include
selected_columns = ['COUNTRY', 'GDP', 'GDP_CAPITA', 'LAND_AREA', 'LIFE_EXPECTANCY', 'ADULT_LITERACY', 'POPULATION', 'UNEMPLOYMENT_RATE', 'INCOME_CLASS']

# %%
# Filter DataFrame for South Asian countries with selected columns
south_asia_df = df[df['COUNTRY'].isin(south_asian_countries)][selected_columns]

# %%
selected_columns
# Out:
# ['COUNTRY',
#  'GDP',
#  'GDP_CAPITA',
#  'LAND_AREA',
#  'LIFE_EXPECTANCY',
#  'ADULT_LITERACY',
#  'POPULATION',
#  'UNEMPLOYMENT_RATE',
#  'INCOME_CLASS']

# %% [markdown]
# # GDP Comparison Bar Chart:
#
# Insight: The bar chart compares the GDP of South Asian countries.

# %%
plt.figure(figsize=(12, 6))
plt.bar(south_asia_df['COUNTRY'], south_asia_df['GDP'], color='skyblue')
plt.xlabel('Country')
plt.ylabel('GDP (in Trillions)')
plt.title('GDP Comparison of South Asian Countries')
plt.show()

# %% [markdown]
# Income Class Distribution Bar Chart:
#
# Insight: The bar chart illustrates the distribution of income classes across South Asian countries.

# %%
# Bar chart for countries and their income classes
plt.figure(figsize=(12, 6))
plt.bar(south_asia_df['COUNTRY'], south_asia_df['INCOME_CLASS'], color='green')
plt.xlabel('Country')
plt.ylabel('Income Class')
plt.title('Income Class of South Asian Countries')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 8))
south_asia_df['INCOME_CLASS'].value_counts().plot.pie(autopct='%1.1f%%', colors=['lightcoral', 'lightgreen', 'lightblue'])
plt.title('Income Class Distribution in South Asian Countries')
plt.show()
plt.show()

# %%
correlation_matrix = south_asia_df[['GDP', 'GDP_CAPITA', 'LAND_AREA', 'LIFE_EXPECTANCY', 'ADULT_LITERACY', 'POPULATION', 'UNEMPLOYMENT_RATE']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap for Selected Variables')
plt.show()

# %% [markdown]
# # Scatter Plot - GDP vs. GDP per Capita:
#
# Insight: The scatter plot shows the relationship between GDP and GDP per Capita.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='GDP', y='GDP_CAPITA', data=south_asia_df, hue='INCOME_CLASS', palette='viridis')
plt.xlabel('GDP (in Trillions)')
plt.ylabel('GDP per Capita')
plt.title('GDP vs. GDP per Capita in South Asian Countries')
plt.show()

# %%
# Generate a color gradient based on the Population
colors = sns.color_palette("YlOrRd", len(south_asia_df))

# Bar chart for Population with multicolor
plt.figure(figsize=(12, 6))
plt.bar(south_asia_df['COUNTRY'], south_asia_df['POPULATION'], color=colors)
plt.xlabel('Country')
plt.ylabel('Population (in Billions)')
plt.title('Population Comparison of South Asian Countries')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='POPULATION', y='LIFE_EXPECTANCY', data=south_asia_df, marker='o', hue='INCOME_CLASS', palette='Set2')
plt.xlabel('Population (in Billions)')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Over Population in South Asian Countries')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='COUNTRY', y='GDP_CAPITA', data=south_asia_df, marker='o', hue='INCOME_CLASS', palette='viridis')
plt.xlabel('Country')
plt.ylabel('GDP per Capita')
plt.title('GDP per Capita Over Time in South Asian Countries')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='INCOME_CLASS', y='UNEMPLOYMENT_RATE', data=south_asia_df, palette='Set3')
plt.xlabel('Income Class')
plt.ylabel('Unemployment Rate')
plt.title('Distribution of Unemployment Rate by Income Class in South Asian Countries')
plt.show()

# %% [markdown]
# # Bar Chart - Adult Literacy Rate Comparison:
#
# Insight: The bar chart compares adult literacy rates among South Asian countries.

# %%
# Generate a color gradient based on the Adult Literacy Rate
colors = sns.color_palette("viridis", len(south_asia_df))

# Bar chart for Adult Literacy Rate with multicolor
plt.figure(figsize=(12, 6))
plt.bar(south_asia_df['COUNTRY'], south_asia_df['ADULT_LITERACY'], color=colors)
plt.xlabel('Country')
plt.ylabel('Adult Literacy Rate')
plt.title('Adult Literacy Rate Comparison in South Asian Countries')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='LAND_AREA', y='LIFE_EXPECTANCY', data=south_asia_df, hue='INCOME_CLASS', palette='viridis')
plt.xlabel('Land Area (in sq. km)')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy vs. Land Area in South Asian Countries')
plt.show()

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.impute import SimpleImputer  # Import SimpleImputer

import numpy as np

# Assuming you have a DataFrame named south_asia_df with relevant columns

# Select features and target variable
features = south_asia_df[['GDP_CAPITA', 'LAND_AREA', 'LIFE_EXPECTANCY', 'ADULT_LITERACY', 'POPULATION', 'UNEMPLOYMENT_RATE']]
target = south_asia_df['GDP']

# Handle missing values using SimpleImputer
imputer = SimpleImputer(strategy='mean')
features_imputed = pd.DataFrame(imputer.fit_transform(features), columns=features.columns)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_imputed, target, test_size=0.2, random_state=42)

# Initialize the linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
predictions = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')

# Example prediction for a new set of features
new_features = np.array([1500, 500000, 75, 90, 150000000, 5]).reshape(1, -1)  # Replace with your values
predicted_gdp = model.predict(new_features)
print(f'Predicted GDP: {predicted_gdp[0]}')
# Out:
# Mean Squared Error: 1.0023241485744792e+22
# R-squared: 0.31039287880871225
# Predicted GDP: 304781100797.5736
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Scatter plot for actual vs. predicted GDP on the test set
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions, color='blue', alpha=0.7)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2, label='Perfect Prediction')
plt.title('Actual vs. Predicted GDP on Test Set')
plt.xlabel('Actual GDP')
plt.ylabel('Predicted GDP')
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Assuming you have a DataFrame named south_asia_df with relevant columns

# Select features and target variable
features = south_asia_df[['GDP_CAPITA', 'LAND_AREA', 'LIFE_EXPECTANCY', 'ADULT_LITERACY', 'POPULATION', 'UNEMPLOYMENT_RATE']]
target = south_asia_df['GDP']

# Handle missing values using SimpleImputer (if not done previously)
imputer = SimpleImputer(strategy='mean')
features_imputed = pd.DataFrame(imputer.fit_transform(features), columns=features.columns)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_imputed, target, test_size=0.2, random_state=42)

# Initialize the Random Forest Regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions on the test set
rf_predictions = rf_model.predict(X_test)

# Evaluate the model
rf_mse = mean_squared_error(y_test, rf_predictions)
rf_r2 = r2_score(y_test, rf_predictions)

print(f'Mean Squared Error (Random Forest): {rf_mse}')
print(f'R-squared (Random Forest): {rf_r2}')
# Out:
# Mean Squared Error (Random Forest): 2.0046402416478144e+22
# R-squared (Random Forest): -0.3792087001326341

# %%
# Scatter plot for actual vs. predicted GDP using Random Forest Regressor on the test set
plt.figure(figsize=(10, 6))
plt.scatter(y_test, rf_predictions, color='green', alpha=0.7)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red', linewidth=2, label='Perfect Prediction')
plt.title('Actual vs. Predicted GDP using Random Forest Regressor')
plt.xlabel('Actual GDP')
plt.ylabel('Predicted GDP (Random Forest)')
plt.legend()
plt.show()
